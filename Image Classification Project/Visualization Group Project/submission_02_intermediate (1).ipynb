# %% [markdown]
# # Submission 2 - Intermediate

# %% [markdown]
# **Instructions**
# - Fill out the 'Basic Information' and 'Simple Hypotheses - Findings / Insights' sections (replace the TODOs with your information)
#   - If your visualization is interactive, create a short video that shows the interactivity (max. 3 min).
# - Export the Jupyter notebook as a HTML file and save it in this repository.
#   - Go to 'File' -> 'Save and Export Notebook As..' -> 'HTML'.
#   - Save it locally in your project folder. You can leave the name as it is.
#   - If you have a video, then add it to the project folder.
#   - Push your local changes to the GitHub repository.
# - Upload the generated HTML for the Moodle submission.
#   - If you have a video, then upload that for the Moodle submission, too.

# %% [markdown]
# ---
# ## Basic Information

# %% [markdown]
# **Team Name:** Handicapped Hamsters

# %% [markdown]
# **Team Members:**
# - Tobias Halmdienst
# - Viktor Szolga
# - Christoph Lasinger
# - Simon Danninger

# %% [markdown]
# **Dataset Description:**
# (max. 75 words)

# %% [markdown]
# The Employee Satisfaction Survey dataset is a data collection covering details of employees within a company like performance evaluation, work hours, accidents, promotions and more. It can be used to gain insight in various aspects of the workplace environment.
# Since some attributes are listed as null, we cleaned these for further processing. Even though, some pre-processing was necessary, this dataset is almost usable as it is.

# %% [markdown]
# ---
# ## Simple Hypotheses - Findings / Insights

# %% [markdown]
# **Instructions:**
# - Add your visualizations (**max. 4**) here
#   - The visualizations should show the findings / insights
# - Add the descriptions for all your findings / insights (**max. 150 words**)
#   - The description should also relate to the visualizations above.

# %% [markdown]
# ### Visualizations

# %% [markdown]
# **1.** Does higher employee satisfaction leads to higher job performance?

# %% [markdown]
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# **2.** Are accidents in the work place correlated with the job type? <br> <br>

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Description

# %% [markdown]
# Design up to 4 visualizations that communicate your key findings effectively. Adhere to the visualization principles and concepts taught in the lecture part.
# Write down your insights/findings for both hypotheses and their visualizations with a maximum of 150 words.

# %% [markdown]
# The first line-plot describes the correlation between the satisfaction of the employee and their last performence evaluation score. One can, through the trend line, immediately notice the slight positive correlation between the two attributes. While inspecting the data further we started to doubt the informative value of the trendline. Due to the slump in the data the trend line gets tilted down. In the attached video one can observe parts next to the outliers.
#
# The second bar-chart displays the distribution of all accidents over all different departments. At first glance, one may disregard the differences as random noise, however after further review, it seems plausible that employees which tend to operate outside of the company facilities are more prone to accidents.
